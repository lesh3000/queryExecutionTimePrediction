# %%
from functions import *
import warnings
warnings.filterwarnings("ignore")

# %%
genLog= loadLog('general_log.json')
genLog.head(3)
# Out:
#                    event_time                        user_host  thread_id  \
# 0  2021-01-14 15:19:54.549896  guest[guest] @  [185.9.209.177]         67
# 1  2021-01-14 15:19:54.489750  guest[guest] @  [185.9.209.177]         67
# 2  2021-01-14 15:19:54.430215  guest[guest] @  [185.9.209.177]         67
#
#    server_id command_type                                           argument
# 0   97408076        Query  /* ApplicationName=DataGrip 2020.2.3 */ select...
# 1   97408076        Query  /* ApplicationName=DataGrip 2020.2.3 */ SET ne...
# 2   97408076        Query                                      SHOW WARNINGS

# %%
slowLog= loadLog('slow_log.json')
slowLog.head(3)
# Out:
#                    start_time                        user_host  \
# 0  2021-01-14 15:11:51.815988  guest[guest] @  [185.9.209.177]
# 1  2021-01-14 15:11:51.749969  guest[guest] @  [185.9.209.177]
# 2  2021-01-14 15:11:51.687122  guest[guest] @  [185.9.209.177]
#
#         query_time lock_time  rows_sent  rows_examined    db  last_insert_id  \
# 0  00:00:00.000093  00:00:00          0              0  tpch               0
# 1  00:00:00.000055  00:00:00          0              0  tpch               0
# 2  00:00:00.000076  00:00:00          0              0  tpch               0
#
#    insert_id  server_id                                           sql_text  \
# 0          0   97408076  /* ApplicationName=DataGrip 2020.2.3 */ SET ne...
# 1          0   97408076                                      SHOW WARNINGS
# 2          0   97408076                                      SHOW WARNINGS
#
#    thread_id
# 0         67
# 1         67
# 2         67

# %% [markdown]
# ## Data Consistency
#
# The further section investigates if data in slow log corresponds to the records available in general log
#
# - timeline review based on number of requests per minute
# - nummber of requests per minute descriptive statistics
# - difference plots
# - requests per user analysis

# %%
compareDates(genLog,slowLog)
# Out:
# General log timeline is over:
# 3:59:00.040352
# _______________________________
# Slow log timeline is over:
# 3:50:57.125391
#         event_time   start_time
# count  5294.000000  5294.000000
# mean      3.041368     2.963355
# std       3.201051     3.148593
# min       0.000000     0.000000
# 25%       1.000000     1.000000
# 50%       1.000000     1.000000
# 75%       4.000000     3.000000
# max      24.000000    25.000000
# Logs provide 204 different values regarding number of requests per minute
# __________________________

# %%
gr1=genLog.groupby(by="user_host").count()
gr2=slowLog.groupby(by="user_host").count()
merged= pd.concat([gr1, gr2], axis=1).fillna(0)
labels = merged.index


gen = merged['event_time']
slow = merged['start_time']

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
fig.set_size_inches(12, 10, forward=True)
rects1 = ax.bar(x - width/2, gen, width, label='General log', color=["thistle"])
rects2 = ax.bar(x + width/2, slow, width, label='Slow log',color=["paleturquoise"])

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Actions by user')
ax.set_title('Actions by user by log')
ax.set_xticks(x)
ax.tick_params(labelrotation=90)
ax.set_xticklabels(labels)
ax.legend()
autolabel(rects1,ax)
autolabel(rects2,ax)
fig.tight_layout()
plt.show()

# %% [markdown]
# ## Conclusion
#
#
# The presented analysis indicate the following differences between slow and general log:
# - timeline difference
# - requests per minute
# - user number
# - actions per user
#
# The data does not contain any query identifier, thus for further analysis of the data available in slow log and  in general log will be studied separetely

# %% [markdown]
# ## General Log addtional analysis
#
# Analyse variables that can impact the query time
#
# - command type
# - server id

# %%
fig = plt.figure(figsize=(18,10))
ax1 = plt.subplot2grid((2,2),(0,0))
colors=[ "thistle","peachpuff","paleturquoise", "c"]
commandType=genLog["command_type"].value_counts()
ax1.pie(commandType,shadow=True, startangle=45, colors=colors)
ax1.legend(labels= commandType.index + " "+ commandType.values.astype("str"))
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
ax1.set_title('Command types allocation')
ax1 = plt.subplot2grid((2,2),(0,1))
serverId=genLog["server_id"].value_counts()


ax1.pie(serverId,shadow=True, startangle=45, colors=colors)
ax1.legend(labels=serverId.index)
ax1.axis('equal')
ax1.set_title('Server allocation')
plt.show()

# %% [markdown]
# ### Result
#
# The variables has no or ittle impact on the execution time variable
#
# - All the requests have been processed by the same server.
# - The type of the request could have a implication on the execution time, but the corresponding data is very unbalanced so it is hard to say if there is any relationships between the command type and execution time.

# %% [markdown]
# ## Slow Log Analysis

# %%
slowLog['sql_text']=slowLog['sql_text'].apply(lambda x: clean(x))
slowLog.head(3)
# Out:
#                    start_time                        user_host  \
# 0  2021-01-14 15:11:51.815988  guest[guest] @  [185.9.209.177]
# 1  2021-01-14 15:11:51.749969  guest[guest] @  [185.9.209.177]
# 2  2021-01-14 15:11:51.687122  guest[guest] @  [185.9.209.177]
#
#         query_time lock_time  rows_sent  rows_examined    db  last_insert_id  \
# 0  00:00:00.000093  00:00:00          0              0  tpch               0
# 1  00:00:00.000055  00:00:00          0              0  tpch               0
# 2  00:00:00.000076  00:00:00          0              0  tpch               0
#
#    insert_id  server_id                   sql_text  thread_id
# 0          0   97408076  SET net_write_timeout=600         67
# 1          0   97408076              SHOW WARNINGS         67
# 2          0   97408076              SHOW WARNINGS         67

# %% [markdown]
# ## Capital Letter Structure
#
# SQL commands oftenwritten in capital letters which could facilitate model trainig
# - Investigate if the words in capital letters are related to SQL commands, it could help to increase model accuracy_

# %%
caps=getCapitalWords(slowLog['sql_text'])
print(*caps)
# Out:
#  STANDARD AFRICA BRAZIL AND PURGE CHINA GERMANY BURNISHED ALGERIA EGYPT CASE Q BRASS GLOBAL INDONESIA SELECT CAN TIN KENYA WARNINGS F DRUM REG FLUSH ROMANIA COMMIT VARIABLES FROM TABLENAME AMERICA JUMBO HIGH PERU POLISHED AUTOMOBILE HOUSEHOLD PROMO VALUE STEEL BEFORE NAME ANODIZED S PACK WHERE COLLATE TRUCK RUSSIA GROUP LIKE ARABIA TABLESCHEMA PKG ECONOMY KEY EUROPE INSERT ARGENTINA PERSON MOROCCO IRAN MACHINERY NICKEL COPPER ETHIOPIA KINGDOM UNITED STATES VIETNAM NULL SLOW CANADA WRAP INDIA LOGS EAST BY ASIA UPDATE B BOX RNG MED SAUDI JAR BRUSHED BINARY IN P SM MIDDLE IRAQ CC SHIP SMALL SHOW AIR ON RAIL NOT BUILDING PLATED AS BAG MAIL MOZAMBIQUE FRANCE FOB LG ORDER NAMES DUPLICATE DELIVER LARGE FURNITURE SET JORDAN COUNT R JAPAN TABLES GENERAL INTO IS URGENT MEDIUM SQLSELECTLIMITDEFAULT SQLSELECTLIMIT LIMIT NOENGINESUBSTITUTIONSTRICTTRANSTABLES

# %% [markdown]
# ### Result
# The abouve review shows that not only SQL commands are written in capital letters

# %% [markdown]
# ## Descriptive Statistics

# %%
pd.set_option('display.float_format', lambda x: '%.9f' % x)
slowLog['query_time']=slowLog['query_time'].map(lambda x: float(str(x[6:])))
slowLog['lock_time']=slowLog['lock_time'].map(lambda x: float(str(x[6:])))
slowLog.describe()
# Out:
#            query_time       lock_time        rows_sent     rows_examined  \
# count 15688.000000000 15688.000000000  15688.000000000   15688.000000000
# mean      0.546454841     0.000155016   8554.359574197  609327.769760326
# std       1.211287087     0.000931420  32730.257214221 1253887.098982423
# min       0.000007000     0.000000000      0.000000000       0.000000000
# 25%       0.000442000     0.000000000      1.000000000       1.000000000
# 50%       0.001310500     0.000072000      1.000000000       1.000000000
# 75%       0.539295000     0.000177000     31.250000000  341595.000000000
# max      11.073425000     0.071033000 241191.000000000 4501838.000000000
#
#        last_insert_id       insert_id          server_id       thread_id
# count 15688.000000000 15688.000000000    15688.000000000 15688.000000000
# mean      0.000000000     0.000000000 97408076.000000000    18.017848037
# std       0.000000000     0.000000000        0.000000000    12.811516408
# ...

# %% [markdown]
# ### Request Length Analysis
# Request length may have impact on the query execution time
#
# #### Request length in number of chars and number of words
# The following section creates and studies additional variables: number of words per request and number of characters per requests.
#
# To comply with SQL logic, the special chars( <,>, <=,>= ) are counted as a separate words

# %%
size= [len(i) for i in slowLog['sql_text']]
size=pd.Series(size)

tokenized=[tf.keras.preprocessing.text.text_to_word_sequence(i.replace(">", " > ").replace("<"," < ").replace(">="," >= ").replace("<="," <= ").replace("="," = "),filters='') for i in slowLog['sql_text']]
words= [len(i) for i in tokenized]
words=pd.Series(words)
desc=pd.DataFrame(data=[size.describe(),words.describe()]).T
desc.columns=['Request Length Chars Nr','Request Length Words Nr']
print(desc)
# Out:
#        Request Length Chars Nr  Request Length Words Nr
# count          15688.000000000          15688.000000000
# mean             181.975140235             26.283465069
# std              217.041693808             33.633663693
# min                4.000000000              1.000000000
# 25%                8.000000000              2.000000000
# 50%               47.000000000              5.000000000
# 75%              293.000000000             42.000000000
# max             1557.000000000            163.000000000

# %%
fig = plt.figure(figsize=(18,10))
ax1 = plt.subplot2grid((2,2),(0,0))
sns.distplot(size, hist=True)
ax1.set_title("Requests length chars density plot")
ax1.set_ylabel("Density")
ax1.set_xlabel("Length in nr of chars")
ax1 = plt.subplot2grid((2,2),(0,1))
ax1.boxplot(size)
ax1.set_title("Requests length boxplot")
ax1.set_ylabel("Length in nr of chars")
ax1.set_xlabel("")

ax1 = plt.subplot2grid((2,2),(1,0))
sns.distplot(words, hist=True)
ax1.set_title("Requests length words density plot")
ax1.set_ylabel("Density")
ax1.set_xlabel("Length in nr of words")
ax1 = plt.subplot2grid((2,2),(1,1))
ax1.boxplot(words)
ax1.set_title("Requests length boxplot")
ax1.set_ylabel("Length in nr of words")
ax1.set_xlabel("")
plt.show()

# %% [markdown]
# ### Query Time & Lock Time
#
# Some descriptive stats over variables query time and lock time

# %%
queryTime=slowLog['query_time']
fig = plt.figure(figsize=(18,10))
ax1 = plt.subplot2grid((2,2),(0,0))
sns.distplot(queryTime,hist=False)
ax1.set_title("Requests execution time density plot")
ax1.set_ylabel("Density")
ax1.set_xlabel("Time sec")
ax1 = plt.subplot2grid((2,2),(0,1))
ax1.boxplot(queryTime)
ax1.set_title("Requests execution time boxplot")
ax1.set_ylabel("Time sec")
ax1.set_xlabel("")


ax1 = plt.subplot2grid((2,2),(1,0))
sns.distplot(slowLog['lock_time'],hist=False)
ax1.set_title("Lock time density plot")
ax1.set_ylabel("Density")
ax1.set_xlabel("Time sec")
ax1 = plt.subplot2grid((2,2),(1,1))
ax1.boxplot(slowLog['lock_time'])
ax1.set_title("Lock time boxplot")
ax1.set_ylabel("Time sec")
ax1.set_xlabel("")

plt.show()

# %% [markdown]
# ### Multivariate analysis
#
# Hypotesis:
# - Lock time impacts query time
# - Char length impacts query time
# - Word length impacts query time

# %%
fig = plt.figure(figsize=(18,10))
ax1 = plt.subplot2grid((2,2),(0,0))
ax1.scatter(queryTime,size, color="lightblue")
ax1.set_title("Query time over request size")
ax1.set_xlabel("Response Time")
ax1.set_ylabel("Chars nr")
ax1 = plt.subplot2grid((2,2),(0,1))
ax1.scatter(queryTime,slowLog['lock_time'], color="lightblue")
ax1.set_title("Query time over lock time")
ax1.set_xlabel("Response Time")
ax1.set_ylabel("Lock Time")


ax1 = plt.subplot2grid((2,2),(1,0))
ax1.scatter(queryTime,words, color="lightblue")
ax1.set_title("Query time over words nr")
ax1.set_xlabel("Response Time")
ax1.set_ylabel("Words Nr")
plt.show()

# %%
print("Pearson correlation chars nr: "+str(size.corr(queryTime)))
print("Pearson correlation words nr: "+str(words.corr(queryTime)))
print("Pearson correlation lock_time nr: "+str(slowLog['lock_time'].corr(queryTime)))
# Out:
# Pearson correlation chars nr: 0.4510769083602558
# Pearson correlation words nr: 0.39594319500583713
# Pearson correlation lock_time nr: 0.02468982808669662

# %% [markdown]
# ### Result:
# There is no significant evidence to say that query time depends on any of those variables

# %% [markdown]
# ### Multivariate Analysis Cont
#
# Descriptive stats over rows sent and rows processed variables
#
#  Hypotesis:
#  - query time depends on number of rows processsed
#  - query time depends n number of rows returned

# %%
fig = plt.figure(figsize=(18,10))
ax1 = plt.subplot2grid((2,2),(0,0))
sns.distplot(slowLog['rows_sent'],hist=True)
ax1.set_title("Histogram output volume")
ax1.set_ylabel("")
ax1.set_xlabel("Rows sent")
ax1 = plt.subplot2grid((2,2),(0,1))
ax1.boxplot(slowLog['rows_sent'])
ax1.set_title("Histogram output volume")
ax1.set_ylabel("Rows sent")
ax1.set_xlabel("")

ax1 = plt.subplot2grid((2,2),(1,0))
sns.distplot(slowLog['rows_examined'],hist=True)
ax1.set_title("Histogram processed rows volume")
ax1.set_ylabel("")
ax1.set_xlabel("Rows examined")
ax1 = plt.subplot2grid((2,2),(1,1))
ax1.boxplot(slowLog['rows_examined'])
ax1.set_title("Histogram processed rows volume")
ax1.set_ylabel("Rows examined")
ax1.set_xlabel("")
plt.show()

# %%
fig = plt.figure(figsize=(18,10))
ax1 = plt.subplot2grid((2,2),(0,0))
ax1.scatter(queryTime,slowLog['rows_examined'], color="lightblue")
ax1.set_title("Query time over processed rows")
ax1.set_xlabel("Response Time")
ax1.set_ylabel("Rows processed")
ax1 = plt.subplot2grid((2,2),(0,1))
ax1.scatter(queryTime,slowLog['rows_sent'], color="lightblue")
ax1.set_title("Query time over output size")
ax1.set_xlabel("Response Time")
ax1.set_ylabel("Rows sent")
plt.show()

# %%
print("Pearson correlation sent rows: "+str(slowLog['rows_sent'].corr(queryTime)))
print("Pearson correlation processed rows: "+str(slowLog['rows_examined'].corr(queryTime)))
# Out:
# Pearson correlation sent rows: 0.20923691826080013
# Pearson correlation processed rows: 0.6702035228578274

# %% [markdown]
# ### Result:
# There is no significant correlation found between number of returned rows and query time.
# The  correlation between number of processed rows and query time is moderate positive correlation between the variables.

# %% [markdown]
# ### Query Time on per User Basis Analysis
#
# - Boxplot over query time on a per user basis

# %%
def perUserStats(df):
    names=df['user_host'].unique()
    loc=[(0,0),(0,1),(1,0),(1,1)]
    fig = plt.figure(figsize=(18,10))
    for i in range(len(names)):
        ax1 = plt.subplot2grid((2,2),loc[i])
        mm=df.loc[df['user_host']==names[i]]['query_time'].T
        ax1.boxplot(mm)
        ax1.set_title(names[i])
        ax1.set_xlabel("Executed requests number: "+ str(len(mm)))
        ax1.set_ylabel("Response time")
    plt.show()
    
perUserStats(slowLog)

# %% [markdown]
# Analysis shows that length of requests may depend on a user role:
# - admin requests have shorter magnitude, up to 0.175 sec
# - query time of guest requests stretches till 11 sec ( max value)

# %% [markdown]
# ### Query Text Analysis
# - 10 most frequent queries
# - group queries by query text and view 5 shortest vs 5 longest queries based on average query time
# - tables called in queries

# %%
slowLog['sql_text'].value_counts()[:10]
# Out:
# SELECT 1                                                                                                                                                                                                                                                     5413
# SELECT count(*) from information_schema.TABLES WHERE TABLE_SCHEMA = 'mysql' AND TABLE_NAME = 'rds_heartbeat2'                                                                                                                                                 968
# SELECT value FROM mysql.rds_heartbeat2                                                                                                                                                                                                                        924
# ...

# %%
slowLog['new_sql_text']= slowLog['sql_text'].apply(lambda x:re.sub('\d{10}',"|number|",x))
slowLog['new_sql_text']= slowLog['new_sql_text'].apply(lambda x:re.sub('\d{2,9}',"|datetime|",x))
grouped_ordered=slowLog.groupby(by="new_sql_text")['query_time'].mean().sort_values(ascending= True)
print("Shortest groupped queries, average query time")  
print("")
for i in range(5):
    print(f"{grouped_ordered[i]}':   {grouped_ordered.index[i]}")
    print("")

print("")
print("Longest groupped queries, average query time")   
print("")
for i in range(len(grouped_ordered)-1,len(grouped_ordered)-6,-1):
    print(f"{grouped_ordered[i]}':   {grouped_ordered.index[i]}")
    i-=1
    print("")
# Out:
# Shortest groupped queries, average query time
#
# 1.3042553191489364e-05':   Quit
#
# 2.6125e-05':   Ping
#
# 4.199999999999999e-05':   set autocommit=0
#
# 7.183333333333334e-05':   SET NAMES utf8mb4
#
# 7.8e-05':   SET NAMES 'utf8mb4' COLLATE 'utf8mb4_general_ci'
#
#
# Longest groupped queries, average query time
#
# 9.398392155737708':   -- using |datetime| as a seed to the RNG select l_returnflag, l_linestatus, sum(l_quantity) as sum_qty, sum(l_extendedprice) as sum_base_price, sum(l_extendedprice * (1 - l_discount)) as sum_disc_price, sum(l_extendedprice * (1 - l_discount) * (1 + l_tax)) as sum_charge, avg(l_quantity) as avg_qty, avg(l_extendedprice) as avg_price, avg(l_discount) as avg_disc, count(*) as count_order from lineitem where l_shipdate <= date '|datetime|-|datetime|-|datetime|' - interval '|datetime|' day group by l_returnflag, l_linestatus order by l_returnflag, l_linestatus
#
# ...

# %%
slowLog['sql_text'].apply(lambda x: x.replace("(", " ").replace(")", " ").replace(",", " ")[x.find("from"): x.find(" ", x.find("from")+7)].strip()).value_counts()
# Out:
#                                      7951
# from lineitem                        1500
# from customer                        1200
# from   select                        1050
# from information_schema.TABLES        968
# from orders                           750
# from partsupp                         600
# from supplier                         600
# from part                             300
# from mysql.rds_replication_status     231
# from mysql.rds_history                231
# from o_orderdate                      150
# from l_shipdate                       150
# from mysql.slow_log                     6
# from mysql.slow_lo                      1
# Name: sql_text, dtype: int64

# %% [markdown]
# 7951 queries do not mention any table <br>
# at least 1050 queries are subqueries

# %%
subqueries=slowLog[slowLog['sql_text'].str.lower().str.contains('\(\ select ')]['query_time'].describe()
select1=slowLog[slowLog['sql_text'].str.lower()== "select 1"]['query_time'].describe()
selectAll=slowLog[slowLog['sql_text'].str.lower().str.contains('select *')]['query_time'].describe()
quit=slowLog[slowLog['sql_text'].str.lower().str.contains('quit')]['query_time'].describe()
using=slowLog[slowLog['sql_text'].str.lower().str.startswith('-- using')]['query_time'].describe()
sett=slowLog[slowLog['sql_text'].str.lower().str.startswith("set")]['query_time'].describe()
selectAt=slowLog[slowLog['sql_text'].str.lower().str.startswith("select @@")]['query_time'].describe()
summ=slowLog[slowLog['sql_text'].str.lower().str.startswith("sum")]['query_time'].describe()
selectCount=slowLog[slowLog['sql_text']== "SELECT count(*) from information_schema.TABLES WHERE TABLE_SCHEMA = 'mysql' AND TABLE_NAME = 'rds_heartbeat2'"]['query_time'].describe()

z=pd.DataFrame([subqueries,select1,selectAll,using,sett,selectAt, quit, selectCount, summ]).T
print("*query: SELECT count(*) from information_schema.TABLES WHERE TABLE_SCHEMA = 'mysql' AND TABLE_NAME = 'rds_heartbeat2'")
z.columns=["subqueries","select 1", "select *", "--using", "set", "select@@", "quit", "*see above", "sum"]
z
# Out:
# *query: SELECT count(*) from information_schema.TABLES WHERE TABLE_SCHEMA = 'mysql' AND TABLE_NAME = 'rds_heartbeat2'
#           subqueries       select 1        select *       --using  \
# count 2850.000000000 5413.000000000 15118.000000000 300.000000000
# mean     1.111708940    0.001009647     0.552616511   6.203185047
# std      1.141573501    0.003838582     1.227443161   3.197644010
# min      0.093502000    0.000048000     0.000048000   2.913935000
# 25%      0.168531750    0.000083000     0.000443000   3.008214750
# 50%      0.406983500    0.000443000     0.001191000   6.192488500
# 75%      2.103261250    0.000566000     0.534373750   9.375888250
# max      4.447489000    0.061180000    11.073425000   9.719274000
#
#                set       select@@         quit    *see above           sum
# count 42.000000000 1132.000000000 47.000000000 968.000000000 300.000000000
# mean   0.000162167    0.000529281  0.000013043   0.001258463   2.305814837
# ...

# %%
import requests

url = 'https://sqlproblemapp.azurewebsites.net/predict'
r = requests.post(url,json={'data':'quit'})

print(r.json())
# Out:
# 1.5811223e-05
